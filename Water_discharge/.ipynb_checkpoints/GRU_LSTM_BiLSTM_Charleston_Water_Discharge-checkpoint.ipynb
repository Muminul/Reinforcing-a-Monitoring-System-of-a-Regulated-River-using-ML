# %% [markdown]
# ## Attribute: Daily Water Discharge (cubic feet/sec (mean))
# ####  Dataset duration 3 year
# ####  No Outliers removed
#
# ## Models: GRU, BiLSTM, LSTM
# #### Early Stopping Callbacks removed (50 epoch is used for all for model comparison)
# #### Prediction = Red, Real data = Blue
#
# ## MAPE, r2 score, train/test plot added

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

import plotly.graph_objects as go
import plotly.express as px

# %%
tf.random.set_seed(1234)

# %%
water_data = pd.read_csv('3year_daily_dis.csv')
water_data
# Out:
#          Date     WD value
# 0      2/1/20  13800     A
# 1      2/2/20  13100     A
# 2      2/3/20  12100     A
# 3      2/4/20  11500     A
# 4      2/5/20  13000     A
# ...       ...    ...   ...
# 1094  1/30/23  23800     P
# 1095  1/31/23  24900     P
# 1096   2/1/23  25300     P
# 1097   2/2/23  23800     P
# 1098   2/3/23  21700     P
#
# [1099 rows x 3 columns]

# %%
water_data['timestamp'] = pd.to_datetime(water_data['Date'])
water_data['water_discharge'] = water_data['WD']
water_data['data_qualification_code'] = water_data['value']

# %%
water_data
# Out:
#          Date     WD value  timestamp  water_discharge data_qualification_code
# 0      2/1/20  13800     A 2020-02-01            13800                       A
# 1      2/2/20  13100     A 2020-02-02            13100                       A
# 2      2/3/20  12100     A 2020-02-03            12100                       A
# 3      2/4/20  11500     A 2020-02-04            11500                       A
# 4      2/5/20  13000     A 2020-02-05            13000                       A
# ...       ...    ...   ...        ...              ...                     ...
# 1094  1/30/23  23800     P 2023-01-30            23800                       P
# 1095  1/31/23  24900     P 2023-01-31            24900                       P
# 1096   2/1/23  25300     P 2023-02-01            25300                       P
# 1097   2/2/23  23800     P 2023-02-02            23800                       P
# 1098   2/3/23  21700     P 2023-02-03            21700                       P
#
# [1099 rows x 6 columns]

# %%
# drop unnecessary colums
water_data =water_data.drop(['Date','WD','value','data_qualification_code'], axis=1)
water_data
# Out:
#       timestamp  water_discharge
# 0    2020-02-01            13800
# 1    2020-02-02            13100
# 2    2020-02-03            12100
# 3    2020-02-04            11500
# 4    2020-02-05            13000
# ...         ...              ...
# 1094 2023-01-30            23800
# 1095 2023-01-31            24900
# 1096 2023-02-01            25300
# 1097 2023-02-02            23800
# 1098 2023-02-03            21700
#
# [1099 rows x 2 columns]

# %%
fig = px.line(water_data.reset_index(), x = 'timestamp', y = 'water_discharge')
fig.update_xaxes(rangeslider_visible = True)
fig.show()
# Out:
# <div>                            <div id="74dd3375-3948-458e-8091-d9f0655982df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74dd3375-3948-458e-8091-d9f0655982df")) {                    Plotly.newPlot(                        "74dd3375-3948-458e-8091-d9f0655982df",                        [{"hovertemplate":"timestamp=%{x}<br>water_discharge=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","20 ...

# %%
# Set the DATE column as the index.
new_water_data = water_data.set_index('timestamp')
new_water_data.head()
# Out:
#             water_discharge
# timestamp
# 2020-02-01            13800
# 2020-02-02            13100
# 2020-02-03            12100
# 2020-02-04            11500
# 2020-02-05            13000

# %%
new_water_data.index
# Out:
# DatetimeIndex(['2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04',
#                '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#                '2020-02-09', '2020-02-10',
#                ...
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03'],
#               dtype='datetime64[ns]', name='timestamp', length=1099, freq=None)

# %%
new_water_data
# Out:
#             water_discharge
# timestamp
# 2020-02-01            13800
# 2020-02-02            13100
# 2020-02-03            12100
# 2020-02-04            11500
# 2020-02-05            13000
# ...                     ...
# 2023-01-30            23800
# 2023-01-31            24900
# 2023-02-01            25300
# 2023-02-02            23800
# 2023-02-03            21700
#
# [1099 rows x 1 columns]

# %%
# finding duplicate
# new_water_data[new_water_data.index.duplicated()]
new_water_data.index.duplicated()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# Drop rows with duplicate index values
final_water_data = new_water_data.loc[~new_water_data.index.duplicated(), :]
final_water_data
# Out:
#             water_discharge
# timestamp
# 2020-02-01            13800
# 2020-02-02            13100
# 2020-02-03            12100
# 2020-02-04            11500
# 2020-02-05            13000
# ...                     ...
# 2023-01-30            23800
# 2023-01-31            24900
# 2023-02-01            25300
# 2023-02-02            23800
# 2023-02-03            21700
#
# [1099 rows x 1 columns]

# %%
# Missing time series row
dt = pd.Series(data = pd.date_range(start=final_water_data.index.min(), end=final_water_data.index.max(), freq = 'D'))
idx = pd. DatetimeIndex(dt)
final_water_data2 = final_water_data.reindex(idx)
final_water_data2
# Out:
#             water_discharge
# 2020-02-01            13800
# 2020-02-02            13100
# 2020-02-03            12100
# 2020-02-04            11500
# 2020-02-05            13000
# ...                     ...
# 2023-01-30            23800
# 2023-01-31            24900
# 2023-02-01            25300
# 2023-02-02            23800
# 2023-02-03            21700
#
# [1099 rows x 1 columns]

# %%
df = final_water_data2
df.head()
# Out:
#             water_discharge
# 2020-02-01            13800
# 2020-02-02            13100
# 2020-02-03            12100
# 2020-02-04            11500
# 2020-02-05            13000

# %%
#Verify that there are no empty cells in any column. The output should be all zeroes.
import numpy as np
df.isin([np.nan, np.inf, -np.inf]).sum()
# Out:
# water_discharge    0
# dtype: int64

# %%
# Plot out the time series
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
data_count = len(final_water_data2)
print(data_count)
# Out:
# 1099

# %%
train_size = int(0.8*data_count)
print(train_size)
test_size = data_count-train_size
print(test_size)
# Out:
# 879
# 220

# %%
training_set = df.iloc[:train_size, 0:1].values
training_set
# Out:
# array([[ 13800],
#        [ 13100],
#        [ 12100],
#        [ 11500],
#        [ 13000],
#        [ 32200],
#        [102000],
#        [107000],
#        [ 88300],
#        [ 71800],
#        [ 93600],
#        [102000],
#        [ 88700],
#        [ 80900],
#        [ 66200],
#        [ 53900],
#        [ 42000],
#        [ 33900],
#        [ 27700],
#        [ 25200],
#        [ 22500],
#        [ 20300],
#        [ 17100],
#        [ 14600],
#        [ 13800],
#        [ 15300],
#        [ 22400],
#        [ 31100],
#        [ 30100],
#        [ 23300],
#        [ 19800],
#        [ 20500],
#        [ 26400],
#        [ 27900],
#        [ 33000],
#        [ 25300],
#        [ 20100],
#        [ 17100],
#        [ 17000],
#        [ 19100],
#        [ 21200],
#        [ 28300],
#        [ 41700],
#        [ 38400],
#        [ 36300],
#        [ 33800],
#        [ 27400],
#        [ 25500],
#        [ 27800],
#        [ 40200],
#        [ 45700],
#        [ 39900],
#        [ 36800],
#        [ 38700],
#        [ 51900],
#        [ 53300],
#        [ 45500],
#        [ 33900],
#        [ 25800],
#        [ 21700],
#        [ 19500],
#        [ 22100],
#        [ 22500],
#        [ 18300],
#        [ 15900],
#        [ 14400],
#        [ 13600],
#        [ 19600],
#        [ 34300],
#        [ 32100],
#        [ 27200],
#        [ 22700],
#        [ 42000],
#        [ 80800],
#        [ 74800],
#        [ 62200],
#        [ 52500],
#        [ 45400],
#        [ 30300],
#        [ 24600],
#        [ 23000],
#        [ 22300],
#        [ 20800],
#        [ 24700],
#        [ 38200],
#        [ 45900],
#        [ 58600],
#        [ 59200],
#        [ 47800],
#        [ 57700],
#        [ 80000],
#        [ 75600],
#        [ 59400],
#        [ 61000],
#        [ 61500],
#        [ 48600],
#        [ 41500],
#        [ 34600],
#        [ 33900],
#        [ 35600],
#        [ 30300],
#        [ 24500],
#        [ 21000],
#        [ 18200],
#        [ 16200],
#        [ 15800],
#        [ 14200],
#        [ 14600],
#        [ 13800],
#        [ 26900],
#        [ 66800],
#        [ 75300],
#        [ 84600],
#        [ 74200],
#        [ 66100],
#        [ 60400],
#        [ 54900],
#        [ 64900],
#        [ 66200],
#        [ 60600],
#        [ 52900],
#        [ 45600],
#        [ 38400],
#        [ 23600],
#        [ 17900],
#        [ 22700],
#        [ 28600],
#        [ 30800],
#        [ 24500],
#        [ 16900],
#        [ 14500],
#        [ 12800],
#        [ 12900],
#        [ 15300],
#        [ 12500],
#        [ 20600],
#        [ 34500],
#        [ 33500],
#        [ 46300],
#        [ 66800],
#        [ 66500],
#        [ 53600],
#        [ 42900],
#        [ 29800],
#        [ 23500],
#        [ 21300],
#        [ 17500],
#        [ 14800],
#        [ 12200],
#        [ 11700],
#        [ 10500],
#        [ 11200],
#        [ 11000],
#        [ 10700],
#        [  8240],
#        [  8000],
#        [  7750],
#        [  7200],
#        [  7370],
#        [  7660],
#        [  7120],
#        [  5560],
#        [  6910],
#        [  7210],
#        [  6060],
#        [  5570],
#        [  6200],
#        [  4730],
#        [  4930],
#        [  6050],
#        [  5840],
#        [  5450],
#        [  4770],
#        [  6130],
#        [  6670],
#        [  6930],
#        [  7560],
#        [  6460],
#        [  6170],
#        [  5250],
#        [  5970],
#        [  7220],
#        [  8880],
#        [ 14200],
#        [ 13600],
#        [  7640],
#        [  5770],
#        [  5080],
#        [  3900],
#        [  5910],
#        [  7340],
#        [  6190],
#        [  6180],
#        [  4680],
#        [  5460],
#        [  6890],
#        [ 15800],
#        [ 26500],
#        [ 31000],
#        [ 20000],
#        [ 13200],
#        [ 10000],
#        [  8220],
#        [  6970],
#        [  7930],
#        [  7290],
#        [ 12400],
#        [  9760],
#        [  7690],
#        [ 17700],
#        [ 18600],
#        [ 23100],
#        [ 20600],
#        [ 30300],
#        [ 36500],
#        [ 33700],
#        [ 32100],
#        [ 29500],
#        [ 20700],
#        [ 13200],
#        [ 10600],
#        [  9800],
#        [  8380],
#        [  6510],
#        [  6350],
#        [  5190],
#        [  6660],
#        [  8620],
#        [  7080],
#        [  6440],
#        [  5590],
#        [  8200],
#        [  7210],
#        [  6930],
#        [  6140],
#        [  5100],
#        [  4190],
#        [  4310],
#        [  5270],
#        [  9150],
#        [  8840],
#        [  6620],
#        [  7060],
#        [ 11100],
#        [ 12700],
#        [  8410],
#        [  7610],
#        [  6630],
#        [  5940],
#        [  5360],
#        [  4320],
#        [  4410],
#        [  5350],
#        [ 10500],
#        [ 10200],
#        [ 12100],
#        [ 11800],
#        [  7160],
#        [  7760],
#        [  6440],
#        [  7080],
#        [  6870],
#        [  6030],
#        [  5660],
#        [  6050],
#        [  5600],
#        [  5790],
#        [  4950],
#        [  3810],
#        [  4970],
#        [  6340],
#        [ 13500],
#        [ 21000],
#        [ 26900],
#        [ 24600],
#        [ 25000],
#        [ 22200],
#        [ 20500],
#        [ 17700],
#        [ 13900],
#        [ 11300],
#        [  9690],
#        [  8800],
#        [  6890],
#        [ 12200],
#        [ 25500],
#        [ 45100],
#        [ 44900],
#        [ 35700],
#        [ 31900],
#        [ 28300],
#        [ 25900],
#        [ 24700],
#        [ 23000],
#        [ 21100],
#        [ 20000],
#        [ 17100],
#        [ 18000],
#        [ 17100],
#        [ 14800],
#        [ 12300],
#        [ 11400],
#        [  9530],
#        [ 10900],
#        [ 10900],
#        [ 15200],
#        [ 17400],
#        [ 14800],
#        [ 22800],
#        [ 37200],
#        [ 34300],
#        [ 29100],
#        [ 24300],
#        [ 20500],
#        [ 17400],
#        [ 13900],
#        [ 12900],
#        [ 18100],
#        [ 27700],
#        [ 32900],
#        [ 36800],
#        [ 34600],
#        [ 29900],
#        [ 25600],
#        [ 22800],
#        [ 22800],
#        [ 22500],
#        [ 22300],
#        [ 32500],
#        [ 49100],
#        [ 41600],
#        [ 34200],
#        [ 29100],
#        [ 25600],
#        [ 24000],
#        [ 24600],
#        [ 28000],
#        [ 36800],
#        [ 41400],
#        [ 36600],
#        [ 31000],
#        [ 26400],
#        [ 22600],
#        [ 20000],
#        [ 17200],
#        [ 16000],
#        [ 13300],
#        [ 12500],
#        [ 11600],
#        [ 11600],
#        [ 10900],
#        [ 10800],
#        [ 11100],
#        [ 10200],
#        [  9750],
#        [  9290],
#        [  7720],
#        [  8220],
#        [  8210],
#        [  9100],
#        [ 36600],
#        [ 59200],
#        [ 53500],
#        [ 40700],
#        [ 32600],
#        [ 28900],
#        [ 29500],
#        [ 28700],
#        [ 25400],
#        [ 22400],
#        [ 21200],
#        [ 18700],
#        [ 18000],
#        [ 16300],
#        [ 14800],
#        [ 14400],
#        [ 18800],
#        [ 29600],
#        [ 33900],
#        [ 35600],
#        [ 35500],
#        [ 37700],
#        [ 44300],
#        [ 45000],
#        [ 49600],
#        [ 46500],
#        [ 40000],
#        [ 36100],
#        [ 38300],
#        [ 36000],
#        [ 34600],
#        [ 34600],
#        [ 37200],
#        [ 53800],
#        [131000],
#        [102000],
#        [ 52200],
#        [ 58100],
#        [ 56000],
#        [ 48100],
#        [ 43200],
#        [ 40200],
#        [ 36600],
#        [ 34700],
#        [ 31600],
#        [ 27700],
#        [ 24900],
#        [ 22600],
#        [ 20000],
#        [ 16100],
#        [ 11900],
#        [ 12700],
#        [ 20600],
#        [ 25600],
#        [ 25500],
#        [ 23600],
#        [ 21700],
#        [ 19600],
#        [ 17400],
#        [ 16200],
#        [ 16500],
#        [ 21400],
#        [ 37400],
#        [ 40200],
#        [ 37600],
#        [ 38900],
#        [ 35500],
#        [ 31300],
#        [ 28100],
#        [ 26100],
#        [ 23900],
#        [ 21700],
#        [ 19100],
#        [ 17400],
#        [ 15500],
#        [ 14100],
#        [ 29000],
#        [ 30600],
#        [ 25600],
#        [ 24000],
#        [ 22400],
#        [ 21200],
#        [ 19800],
#        [ 17600],
#        [ 14300],
#        [ 13400],
#        [ 12500],
#        [  9980],
#        [ 10400],
#        [ 11300],
#        [ 14300],
#        [ 16200],
#        [ 15300],
#        [ 14800],
#        [ 16500],
#        [ 16100],
#        [ 14500],
#        [ 13700],
#        [ 13800],
#        [ 14900],
#        [ 15400],
#        [ 14000],
#        [ 14000],
#        [ 13400],
#        [ 12500],
#        [ 12900],
#        [ 11100],
#        [ 10000],
#        [  9290],
#        [  8660],
#        [  7410],
#        [  7030],
#        [  6890],
#        [  7220],
#        [  7220],
#        [  6280],
#        [  6360],
#        [  5990],
#        [  5240],
#        [  4660],
#        [  5200],
#        [  5020],
#        [  6180],
#        [  6310],
#        [  7050],
#        [  6670],
#        [  7870],
#        [  5750],
#        [  5810],
#        [  5630],
#        [  4720],
#        [  5040],
#        [  4610],
#        [  5120],
#        [  6630],
#        [  7720],
#        [ 13000],
#        [ 21800],
#        [ 24500],
#        [ 33500],
#        [ 34400],
#        [ 24200],
#        [ 17100],
#        [ 11500],
#        [  8620],
#        [  6620],
#        [  5650],
#        [  6220],
#        [  5750],
#        [  5570],
#        [  5070],
#        [  4700],
#        [  4230],
#        [  3990],
#        [  3790],
#        [  3490],
#        [  5470],
#        [  8840],
#        [  9450],
#        [ 12200],
#        [  9780],
#        [  5250],
#        [  4850],
#        [  4440],
#        [  5300],
#        [  5100],
#        [  5640],
#        [  6330],
#        [  6700],
#        [  6190],
#        [  5750],
#        [  4930],
#        [  4890],
#        [  4580],
#        [  4850],
#        [  4540],
#        [  4630],
#        [  4140],
#        [  3720],
#        [  2530],
#        [  2920],
#        [  2960],
#        [  2630],
#        [  3320],
#        [  3760],
#        [  2820],
#        [  2520],
#        [  2750],
#        [  2780],
#        [  2090],
#        [  2530],
#        [  2340],
#        [  2860],
#        [  2270],
#        [  1990],
#        [  2180],
#        [  3620],
#        [  3410],
#        [  3040],
#        [  2660],
#        [  2430],
#        [  3160],
#        [  4290],
#        [  6230],
#        [ 10700],
#        [ 15100],
#        [ 17100],
#        [ 11600],
#        [  6720],
#        [  6410],
#        [  4860],
#        [  3880],
#        [  3680],
#        [  4620],
#        [  5340],
#        [  3950],
#        [  5510],
#        [  8970],
#        [ 17100],
#        [ 36500],
#        [ 26400],
#        [ 16900],
#        [ 10600],
#        [  7090],
#        [  6290],
#        [  5550],
#        [  5400],
#        [  6760],
#        [  5520],
#        [  5560],
#        [  5780],
#        [  5270],
#        [  3820],
#        [  3740],
#        [  3570],
#        [  4010],
#        [  3670],
#        [  4580],
#        [  3410],
#        [  3480],
#        [ 10300],
#        [ 16900],
#        [ 12300],
#        [  8270],
#        [  6870],
#        [  5410],
#        [  4710],
#        [  3260],
#        [  3250],
#        [  4080],
#        [  4050],
#        [  3860],
#        [  3670],
#        [  2960],
#        [  3710],
#        [  4650],
#        [  7250],
#        [  8530],
#        [  6800],
#        [  7190],
#        [  4200],
#        [  3850],
#        [  4360],
#        [  4710],
#        [  4400],
#        [  4310],
#        [  4020],
#        [  4240],
#        [  4670],
#        [  4600],
#        [  4100],
#        [  3110],
#        [  3600],
#        [  3750],
#        [  3960],
#        [  3930],
#        [  4780],
#        [  5260],
#        [  8340],
#        [ 13500],
#        [ 12800],
#        [ 12000],
#        [ 11800],
#        [ 11500],
#        [ 11300],
#        [  8780],
#        [  5440],
#        [  5150],
#        [  6370],
#        [  5330],
#        [  6320],
#        [  5980],
#        [  6820],
#        [  7700],
#        [  6810],
#        [  5270],
#        [  5370],
#        [  5340],
#        [  4240],
#        [  3000],
#        [  3800],
#        [  5900],
#        [  5410],
#        [  5640],
#        [  5580],
#        [  4950],
#        [  6110],
#        [  5600],
#        [  5650],
#        [  5750],
#        [  4970],
#        [  4450],
#        [  3690],
#        [  2850],
#        [  2880],
#        [  3670],
#        [  4680],
#        [  2930],
#        [  2660],
#        [  4230],
#        [  4700],
#        [  4430],
#        [  5120],
#        [  5100],
#        [  4350],
#        [  4080],
#        [  4460],
#        [  4530],
#        [  5510],
#        [  5130],
#        [  4930],
#        [  4670],
#        [  3390],
#        [  3800],
#        [  3970],
#        [  3990],
#        [  4050],
#        [  6180],
#        [  7870],
#        [  8170],
#        [ 14100],
#        [ 50200],
#        [ 57700],
#        [ 48800],
#        [ 38200],
#        [ 29600],
#        [ 19500],
#        [ 14600],
#        [ 18900],
#        [ 40900],
#        [ 41200],
#        [ 38000],
#        [ 28600],
#        [ 21800],
#        [ 15400],
#        [ 13900],
#        [ 11500],
#        [ 11600],
#        [ 10300],
#        [ 19000],
#        [ 21400],
#        [ 19000],
#        [ 16100],
#        [ 14200],
#        [ 13000],
#        [ 10500],
#        [  9310],
#        [  8740],
#        [  8900],
#        [  7990],
#        [  7460],
#        [  6660],
#        [  6650],
#        [  7980],
#        [ 40200],
#        [ 75900],
#        [ 65300],
#        [ 46800],
#        [ 38000],
#        [ 30100],
#        [ 25000],
#        [ 19300],
#        [ 14400],
#        [ 11200],
#        [ 10800],
#        [  9790],
#        [  9630],
#        [ 10600],
#        [ 16200],
#        [ 18200],
#        [ 24100],
#        [ 20200],
#        [ 17300],
#        [ 17400],
#        [ 19800],
#        [ 47600],
#        [ 63200],
#        [ 55300],
#        [ 44400],
#        [ 33900],
#        [ 30100],
#        [ 27400],
#        [ 22900],
#        [ 19000],
#        [ 15900],
#        [ 19500],
#        [ 24300],
#        [ 27700],
#        [ 34600],
#        [ 33400],
#        [ 30500],
#        [ 25700],
#        [ 23700],
#        [ 23900],
#        [ 21800],
#        [ 19200],
#        [ 20000],
#        [ 17900],
#        [ 15700],
#        [ 14800],
#        [ 13400],
#        [ 11600],
#        [ 12800],
#        [ 15000],
#        [ 16400],
#        [ 14700],
#        [ 11100],
#        [  9470],
#        [  8720],
#        [  9650],
#        [ 10000],
#        [ 10700],
#        [ 13900],
#        [ 13200],
#        [ 10800],
#        [ 13300],
#        [ 21900],
#        [ 37600],
#        [ 34800],
#        [ 30800],
#        [ 25700],
#        [ 21000],
#        [ 18200],
#        [ 15600],
#        [ 12800],
#        [ 12000],
#        [ 10500],
#        [ 10700],
#        [ 12400],
#        [ 14500],
#        [ 17000],
#        [ 14600],
#        [ 12600],
#        [ 12600],
#        [ 11200],
#        [ 11700],
#        [ 11300],
#        [ 10400],
#        [  9050],
#        [  9220],
#        [ 11200],
#        [ 10900],
#        [  9630],
#        [ 11200],
#        [ 10300],
#        [ 18200],
#        [ 51300],
#        [ 75000],
#        [ 62200],
#        [ 40200],
#        [ 27400],
#        [ 20700],
#        [ 15700],
#        [ 11600],
#        [ 10600],
#        [ 11400],
#        [ 11000],
#        [ 10500],
#        [  8140],
#        [  7210],
#        [  7370],
#        [  6550],
#        [  7000],
#        [  8620],
#        [ 20000],
#        [ 22900],
#        [ 28600],
#        [ 40700],
#        [ 43300],
#        [ 34500],
#        [ 28500],
#        [ 24700],
#        [ 22100],
#        [ 20100],
#        [ 17400],
#        [ 13200],
#        [  8220],
#        [  6400],
#        [  4880],
#        [  9220],
#        [ 10100],
#        [  9340],
#        [  7730],
#        [  6320],
#        [ 10900],
#        [  9600],
#        [  9800],
#        [  8280],
#        [ 11800],
#        [ 10600],
#        [  8100],
#        [  6010],
#        [  5260],
#        [ 10800],
#        [  7940],
#        [  6770],
#        [  5980],
#        [ 12300],
#        [ 19200]])

# %%
len(training_set)
# Out:
# 879

# %%
testing_set = df.iloc[train_size:, 0:1].values
testing_set.shape
# Out:
# (220, 1)

# %%
df['water_discharge'][:train_size].plot(figsize=(16,4),legend=True)
df['water_discharge'][train_size:].plot(figsize=(16,4),legend=True)
plt.legend(['Training set ','Test set'])
plt.title('Water Discharge')
plt.show()

# %%
# Feature scaling to optimize the training set
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Create a data structure with 1 timesteps and 1 output
# Format it into a three-dimensional array for use in our LSTM model
X_train = []
y_train = []
for i in range(1, train_size):
    X_train.append(training_set_scaled[i-1:i, 0]) # Appending previous 1 data.
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping (LSMT Model needs to be 3- dimensional) following format (values, time-steps, 1 dimensional output).
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (878, 1, 1)

# %%
import keras
def fit_model(model):
    
#-----Early stop implementation-----  
#     early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',
#                                                patience = 10)
#     history = model.fit(X_train, y_train, epochs = 50,  
#                         validation_split = 0.2,
#                         batch_size = 16, shuffle = False, 
#                         callbacks = [early_stop])
    
# ------ without Early stop ----
    history = model.fit(X_train, y_train, epochs = 50,  
                        validation_split = 0.2,
                        batch_size = 16, shuffle = False 
                        )    
    return history

# %%
# Create GRU model
def create_gru(units):
    model = Sequential()
    # Input layer
    model.add(GRU (units = units, return_sequences = True, 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_gru = create_gru(64)

# %%
history_gru = fit_model(model_gru)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 2s 11ms/step - loss: 0.0247 - val_loss: 0.0089
# Epoch 2/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0068
# Epoch 3/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 4/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 5/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 6/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 7/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 8/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 9/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 10/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 11/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 12/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 13/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 14/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 15/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 16/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 17/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 18/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 19/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 20/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 21/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 22/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 23/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 24/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 25/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 26/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 27/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 28/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 29/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 30/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 31/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 32/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 33/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 34/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 35/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 36/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 37/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 38/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 39/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 40/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 41/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 42/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 43/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 44/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 45/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 46/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 47/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 48/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 49/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 50/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0030

# %%
# Create BiLSTM model
def create_bilstm(units):
    model = Sequential()
    # Input layer
    model.add(Bidirectional(
              LSTM(units = units, return_sequences=True), 
              input_shape=(X_train.shape[1], X_train.shape[2])))
    # Hidden layer
    model.add(Bidirectional(LSTM(units = units)))
    model.add(Dense(1))
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_bilstm = create_bilstm(64)

# %%
history_bilstm = fit_model(model_bilstm)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 4s 19ms/step - loss: 0.0259 - val_loss: 0.0075
# Epoch 2/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0115 - val_loss: 0.0059
# Epoch 3/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0042
# Epoch 4/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 5/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 6/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 7/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 8/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 9/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 10/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 11/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 12/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 13/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 14/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 15/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 16/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 17/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 18/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 19/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 20/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 21/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 22/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 23/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 24/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 25/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 26/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 27/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 28/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 29/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 30/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 31/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 32/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 33/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 34/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 35/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 36/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 37/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 38/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 39/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 40/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 41/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 42/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 43/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 44/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 45/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 46/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 47/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 48/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 49/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 50/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031

# %%
# creating LSTM model
model_lstm = Sequential()

# Adding first LSTM layer and some dropout Dropout regularisation
model_lstm.add(LSTM(units=100, return_sequences=True, input_shape = (X_train.shape[1], 1)))
model_lstm.add(Dropout(0.1))

# Adding second LSTM layer and some dropout Dropout regularisation
model_lstm.add(LSTM(units=100, return_sequences=True))
model_lstm.add(Dropout(0.1))

# Adding third LSTM layer and some dropout Dropout regularisation
model_lstm.add(LSTM(units=100, return_sequences=True))
model_lstm.add(Dropout(0.1))

# Adding fourth LSTM layer and some dropout Dropout regularisation
model_lstm.add(LSTM(units=100, return_sequences=True))
model_lstm.add(Dropout(0.1))

# Adding fifth LSTM layer and some dropout Dropout regularisation
model_lstm.add(LSTM(units=100))
model_lstm.add(Dropout(0.1))

# Adding the Output Layer
model_lstm.add(Dense(units=1))

# Compiling the model
# Because we're doing regression hence mean_squared_error
model_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 5s 26ms/step - loss: 0.0303 - val_loss: 0.0130
# Epoch 2/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0229 - val_loss: 0.0120
# Epoch 3/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0218 - val_loss: 0.0117
# Epoch 4/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.0057
# Epoch 5/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 6/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 7/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 8/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 9/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 10/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 11/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 12/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 13/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 14/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 15/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 16/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 17/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 18/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 19/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 20/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 21/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 22/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 23/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 24/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 25/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 26/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 27/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 28/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 29/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 30/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 31/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 32/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 33/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 34/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 35/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 36/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 37/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 38/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 39/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 40/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 41/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 42/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 43/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 44/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 45/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 46/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 47/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 48/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 49/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 50/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0039

# %%
# Evaluating The Model
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
 
plot_loss (history_gru, 'GRU')
plot_loss (history_bilstm, 'BiLSTM')
plot_loss (history_lstm, 'LSTM')

# %%
# We will concatenate the dataset and then scale them, as the last 1 data needs to be from training set
dataset_total = df['water_discharge']
inputs = dataset_total[len(dataset_total) - len(testing_set) - 1:].values
inputs = inputs.reshape(-1,1) # reshape(-1,1) means one column with all rows
inputs = sc.transform(inputs)

X_test = []
for i in range(1, test_size+1): # 1+5276(test size)
    X_test.append(inputs[i-1:i, 0])

X_test = np.array(X_test)
# 3D format for LSTM
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
inputs.shape
# Out:
# (221, 1)

# %%
X_test.shape
# Out:
# (220, 1, 1)

# %%
#preict the model
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = sc.inverse_transform(prediction)
    return prediction
prediction_gru = prediction(model_gru)
prediction_bilstm = prediction(model_bilstm)
prediction_lstm = prediction(model_lstm)
# Out:
# 7/7 [==============================] - 0s 906us/step
# 7/7 [==============================] - 1s 1ms/step
# 7/7 [==============================] - 1s 2ms/step

# %%
# Plot test data vs prediction
# Prediction is on top of real data
def plot_future(prediction, model_name, y_test):
    plt.figure(figsize=(12, 6))
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), 
             label='Real data', color='b')
    plt.plot(np.arange(range_future), 
             np.array(prediction),label='Prediction',color='r')
    
    plt.title('Real data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (Days)')
    plt.ylabel('Daily water discharge (cubic feet/sec (mean))')
 
plot_future(prediction_gru, 'GRU', testing_set)
plot_future(prediction_bilstm, 'BiLSTM', testing_set)
plot_future(prediction_lstm, 'LSTM', testing_set)

# %%
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions-actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    mape= np.mean(np.abs(errors/actual)*100)
    
    print(model_name + ':')
    print('Mean Absolute Error (MAE): {:.4f}'.format(mae))
    print('Mean Squared Error (MSE): {:.4f}'.format(mse))
    print('Root Mean Square Error(RMSE): {:.4f}'.format(rmse))
    print('Mean Absolute Percentage Error(MAPE): {:.4f}'.format(mape))
    print('')
evaluate_prediction(prediction_gru, testing_set, 'GRU')
evaluate_prediction(prediction_bilstm, testing_set, 'Bidirectiona LSTM')
evaluate_prediction(prediction_lstm, testing_set, 'LSTM')
# Out:
# GRU:
# Mean Absolute Error (MAE): 2560.1802
# Mean Squared Error (MSE): 18511697.7992
# Root Mean Square Error(RMSE): 4302.5223
# Mean Absolute Percentage Error(MAPE): 17.2786
#
# Bidirectiona LSTM:
# Mean Absolute Error (MAE): 2628.6408
# Mean Squared Error (MSE): 19008515.0099
# Root Mean Square Error(RMSE): 4359.8756
# Mean Absolute Percentage Error(MAPE): 18.1089
#
# LSTM:
# Mean Absolute Error (MAE): 3222.3714
# Mean Squared Error (MSE): 23883982.9495
# Root Mean Square Error(RMSE): 4887.1242
# Mean Absolute Percentage Error(MAPE): 22.2209

# %%
from sklearn.metrics import r2_score

GRU_r2 = r2_score(testing_set, prediction_gru)
print(f'R2 score of GRU: {GRU_r2}')

BiLSTM_r2 = r2_score(testing_set, prediction_bilstm)
print(f'R2 score of BiLSTM: {BiLSTM_r2}')

LSTM_r2 = r2_score(testing_set, prediction_lstm)
print(f'R2 score of LSTM: {LSTM_r2}')
# Out:
# R2 score of GRU: 0.7670327518977123
# R2 score of BiLSTM: 0.760780373556125
# R2 score of LSTM: 0.6994232597239927
